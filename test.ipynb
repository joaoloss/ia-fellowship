# %%
import editdistance

# %%
editdistance.eval("avenida paulista, nº 2300 andar pilotis, bela vista\nsão paulo - sp\n01310300", "avenida paulista, nº 2300 andar pilotis, bela vista,são paulo - sp,")
# Out:
# 10

# %%
from utils.type_resolution import TypeResolver

t = TypeResolver()
t.resolve("avenida paulista, nº 2300 andar pilotis, bela vista\nsão paulo - sp\n01310300")
# Out:
# 'string'

# %%
a = t.resolve("222/5--009")
# Out:
# 0222-09-05 00:00:00
